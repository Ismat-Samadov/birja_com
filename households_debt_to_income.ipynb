# %%
import pandas as pd
data=pd.read_html('https://tradingeconomics.com/country-list/households-debt-to-income?continent=europe')

# %%
type(data)
# Out:
# list

# %%
data
# Out:
# [           Country    Last  Previous Reference Unit
#  0          Denmark  205.00    214.00    Dec/21    %
#  1           Norway  201.00    208.00    Dec/21    %
#  2      Netherlands  184.00    189.00    Dec/21    %
#  3           Sweden  172.00    172.00    Dec/21    %
#  4           Cyprus  131.00    128.00    Dec/20    %
#  5          Finland  118.00    115.00    Dec/20    %
#  6          Ireland  107.00    112.00    Dec/20    %
#  7          Belgium  106.00    104.00    Dec/20    %
#  8           France  102.00     98.12    Dec/20    %
#  9        Euro Area   96.79     96.19    Dec/21    %
#  10           Spain   94.93     93.01    Dec/20    %
#  11        Portugal   94.32     92.93    Dec/21    %
#  12         Germany   87.16     84.70    Dec/20    %
#  13         Austria   85.28     82.75    Dec/20    %
#  14        Slovakia   72.24     69.39    Dec/20    %
#  15         Estonia   70.26     67.20    Dec/20    %
#  16           Italy   64.36     61.69    Dec/20    %
# ...

# %%
df=data[0:1][0]
df
# Out:
#            Country    Last  Previous Reference Unit
# 0          Denmark  205.00    214.00    Dec/21    %
# 1           Norway  201.00    208.00    Dec/21    %
# 2      Netherlands  184.00    189.00    Dec/21    %
# 3           Sweden  172.00    172.00    Dec/21    %
# 4           Cyprus  131.00    128.00    Dec/20    %
# 5          Finland  118.00    115.00    Dec/20    %
# 6          Ireland  107.00    112.00    Dec/20    %
# 7          Belgium  106.00    104.00    Dec/20    %
# 8           France  102.00     98.12    Dec/20    %
# 9        Euro Area   96.79     96.19    Dec/21    %
# 10           Spain   94.93     93.01    Dec/20    %
# 11        Portugal   94.32     92.93    Dec/21    %
# 12         Germany   87.16     84.70    Dec/20    %
# 13         Austria   85.28     82.75    Dec/20    %
# 14        Slovakia   72.24     69.39    Dec/20    %
# 15         Estonia   70.26     67.20    Dec/20    %
# 16           Italy   64.36     61.69    Dec/20    %
# ...

# %%
df['Reference'][df['Reference']=='Dec/21']='31/12/2021'
df['Reference'][df['Reference']=='Dec/20']='31/12/2020'

df
# Out:
# C:\Users\Ismat\AppData\Local\Temp/ipykernel_10988/412991781.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Reference'][df['Reference']=='Dec/21']='31/12/2021'
# C:\Users\Ismat\AppData\Local\Temp/ipykernel_10988/412991781.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Reference'][df['Reference']=='Dec/20']='31/12/2020'
#            Country    Last  Previous   Reference Unit
# 0          Denmark  205.00    214.00  31/12/2021    %
# 1           Norway  201.00    208.00  31/12/2021    %
# 2      Netherlands  184.00    189.00  31/12/2021    %
# ...

# %%
import datetime as dt
#pd.to_datetime(df['Reference'])
#df['Reference'].apply(lambda x: datetime.datetime.strptime(x, '%m/%d/%Y %I:%M:%S') if type(x)==str else np.NaN)
df['Date']=pd.to_datetime(df['Reference'])
df['Year']=df['Date'].dt.year

# %%
df
# Out:
#            Country    Last  Previous   Reference Unit       Date  Year
# 0          Denmark  205.00    214.00  31/12/2021    % 2021-12-31  2021
# 1           Norway  201.00    208.00  31/12/2021    % 2021-12-31  2021
# 2      Netherlands  184.00    189.00  31/12/2021    % 2021-12-31  2021
# 3           Sweden  172.00    172.00  31/12/2021    % 2021-12-31  2021
# 4           Cyprus  131.00    128.00  31/12/2020    % 2020-12-31  2020
# 5          Finland  118.00    115.00  31/12/2020    % 2020-12-31  2020
# 6          Ireland  107.00    112.00  31/12/2020    % 2020-12-31  2020
# 7          Belgium  106.00    104.00  31/12/2020    % 2020-12-31  2020
# 8           France  102.00     98.12  31/12/2020    % 2020-12-31  2020
# 9        Euro Area   96.79     96.19  31/12/2021    % 2021-12-31  2021
# 10           Spain   94.93     93.01  31/12/2020    % 2020-12-31  2020
# 11        Portugal   94.32     92.93  31/12/2021    % 2021-12-31  2021
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=27,9
plt.grid()
plt.plot(df['Last'],df['Year'],color='green',linewidth=3,alpha=.99,linestyle='-',
         marker='o',markersize=10, markerfacecolor='red',markeredgewidth=3)
#plt.plot(round(data),color='green',linewidth=3,alpha=.99,
#linestyle='-',marker='o',markersize=10, markerfacecolor='red',markeredgewidth=3)
